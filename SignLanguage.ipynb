# %%
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
# %pip install mediapipe
import mediapipe as mp
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.10.0.84)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 12.8 MB/s eta 0:00:00
# Downloading protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 22.3 MB/s eta 0:00:00
# Downloading sounddevice-0.5.0-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.5 which is incompatible.
# Successfully installed mediapipe-0.10.15 protobuf-4.25.5 sounddevice-0.5.0

# %%
from google.colab import drive
drive.mount('/content/drive')

dataset_path = '/content/drive/My Drive/Datasets/Greetings'
# Out:
# Mounted at /content/drive

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

mp_holistic = mp.solutions.holistic

def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, lh, rh])

def convert_video_to_pose_embedded_np_array(video_path, frames_to_extract=45):
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        raise ValueError(f"Unable to open video file: {video_path}")

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    np_array = []

    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        if total_frames >= frames_to_extract:
            frame_indices = np.linspace(0, total_frames - 1, frames_to_extract, dtype=int)
            for i in frame_indices:
                cap.set(cv2.CAP_PROP_POS_FRAMES, i)
                ret, frame = cap.read()
                if not ret:
                    break
                image, results = mediapipe_detection(frame, holistic)
                keypoints = extract_keypoints(results)
                np_array.append(keypoints)
        else:
            key_points_shape = None
            for i in range(total_frames):
                ret, frame = cap.read()
                if not ret:
                    break
                image, results = mediapipe_detection(frame, holistic)
                keypoints = extract_keypoints(results)
                if key_points_shape is None:
                    key_points_shape = keypoints.shape
                np_array.append(keypoints)

            for _ in range(frames_to_extract - total_frames):
                np_array.append(np.zeros(shape=key_points_shape))

    cap.release()
    return np.array(np_array)

def process_dataset(dataset_path, frames_to_extract=45):
    labels = []
    data = []
    label_map = {folder: idx for idx, folder in enumerate(os.listdir(dataset_path))}

    for folder in os.listdir(dataset_path):
        folder_path = os.path.join(dataset_path, folder)
        if not os.path.isdir(folder_path):
            continue
        for video_file in os.listdir(folder_path):
            video_path = os.path.join(folder_path, video_file)
            np_array = convert_video_to_pose_embedded_np_array(video_path, frames_to_extract)
            data.append(np_array)
            labels.append(label_map[folder])

    data = np.array(data)
    labels = np.array(labels)
    return data, labels, label_map

# %%
frames_to_extract = 45

data, labels, label_map = process_dataset(dataset_path, frames_to_extract)

X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, random_state=42)

input_shape = (frames_to_extract, data.shape[2])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization
from tensorflow.keras.optimizers import Adam

model = Sequential()

model.add(Bidirectional(LSTM(128, return_sequences=True, activation='relu'), input_shape=input_shape))
model.add(Dropout(0.5))
model.add(BatchNormalization())

model.add(Bidirectional(LSTM(128, return_sequences=True, activation='relu')))
model.add(Dropout(0.5))
model.add(BatchNormalization())

model.add(Bidirectional(LSTM(64, return_sequences=False, activation='relu')))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))

model.add(Dense(len(label_map), activation='softmax'))

model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional_18 (Bidirectional)     │ (None, 45, 256)             │         396,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_38 (Dropout)                 │ (None, 45, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 45, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_19 (Bidirectional)     │ (None, 45, 256)             │         394,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_39 (Dropout)                 │ (None, 45, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 45, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_20 (Bidirectional)     │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_40 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_30 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_41 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_31 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 9)                   │             297 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 967,561 (3.69 MB)
#  Trainable params: 966,537 (3.69 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=16, epochs=200)
# Out:
# Epoch 1/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6476 - loss: 0.9309 - val_accuracy: 0.6776 - val_loss: 1.1353
# Epoch 2/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6793 - loss: 0.8431 - val_accuracy: 0.6382 - val_loss: 1.7909
# Epoch 3/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.6588 - loss: 0.8501 - val_accuracy: 0.6316 - val_loss: 2.2244
# Epoch 4/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6619 - loss: 0.8758 - val_accuracy: 0.6513 - val_loss: 1.8254
# Epoch 5/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6828 - loss: 0.7962 - val_accuracy: 0.5987 - val_loss: 2.7199
# Epoch 6/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.6777 - loss: 0.7707 - val_accuracy: 0.6118 - val_loss: 4.1298
# Epoch 7/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.7076 - loss: 0.8214 - val_accuracy: 0.6645 - val_loss: 1.4022
# Epoch 8/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.6744 - loss: 0.8327 - val_accuracy: 0.7039 - val_loss: 1.6637
# Epoch 9/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.6987 - loss: 0.7665 - val_accuracy: 0.7368 - val_loss: 1.2679
# Epoch 10/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.6612 - loss: 0.8042 - val_accuracy: 0.7303 - val_loss: 1.0639
# Epoch 11/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7091 - loss: 0.7389 - val_accuracy: 0.7368 - val_loss: 1.4928
# Epoch 12/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.6824 - loss: 0.8046 - val_accuracy: 0.7303 - val_loss: 1.1899
# Epoch 13/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.7171 - loss: 0.7044 - val_accuracy: 0.7237 - val_loss: 1.3831
# Epoch 14/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6779 - loss: 0.7896 - val_accuracy: 0.7500 - val_loss: 1.1324
# Epoch 15/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.6521 - loss: 0.9018 - val_accuracy: 0.7829 - val_loss: 0.9365
# Epoch 16/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7033 - loss: 0.7089 - val_accuracy: 0.7434 - val_loss: 1.5116
# Epoch 17/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7116 - loss: 0.7302 - val_accuracy: 0.6908 - val_loss: 1.2644
# Epoch 18/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.6989 - loss: 0.7869 - val_accuracy: 0.7697 - val_loss: 1.1622
# Epoch 19/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.6960 - loss: 0.7316 - val_accuracy: 0.7368 - val_loss: 1.4566
# Epoch 20/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7358 - loss: 0.6287 - val_accuracy: 0.7829 - val_loss: 0.9540
# Epoch 21/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7016 - loss: 0.7374 - val_accuracy: 0.7895 - val_loss: 1.1483
# Epoch 22/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7116 - loss: 0.6925 - val_accuracy: 0.7697 - val_loss: 1.3219
# Epoch 23/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7445 - loss: 0.6539 - val_accuracy: 0.8026 - val_loss: 1.3914
# Epoch 24/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.7582 - loss: 0.6632 - val_accuracy: 0.8289 - val_loss: 0.8525
# Epoch 25/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.7886 - loss: 0.5855 - val_accuracy: 0.7763 - val_loss: 1.1098
# Epoch 26/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7652 - loss: 0.6427 - val_accuracy: 0.7961 - val_loss: 0.7032
# Epoch 27/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7188 - loss: 0.6904 - val_accuracy: 0.7961 - val_loss: 0.6875
# Epoch 28/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7618 - loss: 0.6085 - val_accuracy: 0.7829 - val_loss: 0.8793
# Epoch 29/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7553 - loss: 0.6162 - val_accuracy: 0.7500 - val_loss: 1.0280
# Epoch 30/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7645 - loss: 0.6358 - val_accuracy: 0.7829 - val_loss: 1.0929
# Epoch 31/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7809 - loss: 0.5483 - val_accuracy: 0.8092 - val_loss: 0.9636
# Epoch 32/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8180 - loss: 0.5166 - val_accuracy: 0.8158 - val_loss: 0.8566
# Epoch 33/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7921 - loss: 0.5460 - val_accuracy: 0.7632 - val_loss: 1.4358
# Epoch 34/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7709 - loss: 0.5608 - val_accuracy: 0.7895 - val_loss: 0.9409
# Epoch 35/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7923 - loss: 0.5543 - val_accuracy: 0.7961 - val_loss: 0.9595
# Epoch 36/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7762 - loss: 0.6137 - val_accuracy: 0.8158 - val_loss: 0.8362
# Epoch 37/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7565 - loss: 0.6270 - val_accuracy: 0.7697 - val_loss: 0.9472
# Epoch 38/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.7665 - loss: 0.5915 - val_accuracy: 0.8421 - val_loss: 0.6869
# Epoch 39/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.7879 - loss: 0.5749 - val_accuracy: 0.8026 - val_loss: 1.0427
# Epoch 40/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8042 - loss: 0.5611 - val_accuracy: 0.7895 - val_loss: 1.3604
# Epoch 41/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7595 - loss: 0.5347 - val_accuracy: 0.7368 - val_loss: 1.7194
# Epoch 42/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7670 - loss: 0.5511 - val_accuracy: 0.8158 - val_loss: 1.0102
# Epoch 43/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8248 - loss: 0.4460 - val_accuracy: 0.7632 - val_loss: 1.8954
# Epoch 44/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.7710 - loss: 0.5405 - val_accuracy: 0.8224 - val_loss: 1.1624
# Epoch 45/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8256 - loss: 0.4797 - val_accuracy: 0.8289 - val_loss: 0.9037
# Epoch 46/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8235 - loss: 0.4739 - val_accuracy: 0.8224 - val_loss: 0.9720
# Epoch 47/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8223 - loss: 0.4662 - val_accuracy: 0.8026 - val_loss: 1.3006
# Epoch 48/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7985 - loss: 0.5291 - val_accuracy: 0.8421 - val_loss: 0.7979
# Epoch 49/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7955 - loss: 0.5760 - val_accuracy: 0.7829 - val_loss: 0.9868
# Epoch 50/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7902 - loss: 0.5611 - val_accuracy: 0.8092 - val_loss: 1.2340
# Epoch 51/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.7740 - loss: 0.5339 - val_accuracy: 0.8092 - val_loss: 1.4753
# Epoch 52/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.7839 - loss: 0.5196 - val_accuracy: 0.8355 - val_loss: 0.7976
# Epoch 53/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8242 - loss: 0.4459 - val_accuracy: 0.8618 - val_loss: 0.7105
# Epoch 54/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8285 - loss: 0.4353 - val_accuracy: 0.8092 - val_loss: 1.1530
# Epoch 55/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8021 - loss: 0.4581 - val_accuracy: 0.8224 - val_loss: 1.0105
# Epoch 56/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.7995 - loss: 0.4849 - val_accuracy: 0.7697 - val_loss: 2.9708
# Epoch 57/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8266 - loss: 0.4681 - val_accuracy: 0.8618 - val_loss: 1.0242
# Epoch 58/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8065 - loss: 0.4825 - val_accuracy: 0.8553 - val_loss: 0.8199
# Epoch 59/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.7972 - loss: 0.4868 - val_accuracy: 0.8355 - val_loss: 1.3850
# Epoch 60/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8165 - loss: 0.4684 - val_accuracy: 0.8158 - val_loss: 1.4094
# Epoch 61/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8113 - loss: 0.4693 - val_accuracy: 0.8158 - val_loss: 1.8080
# Epoch 62/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7785 - loss: 0.5407 - val_accuracy: 0.8553 - val_loss: 1.1063
# Epoch 63/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8175 - loss: 0.5791 - val_accuracy: 0.8421 - val_loss: 1.1301
# Epoch 64/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7729 - loss: 1.0447 - val_accuracy: 0.8289 - val_loss: 0.8999
# Epoch 65/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7895 - loss: 0.5366 - val_accuracy: 0.7961 - val_loss: 0.8269
# Epoch 66/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8135 - loss: 0.5525 - val_accuracy: 0.8026 - val_loss: 0.8539
# Epoch 67/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8192 - loss: 0.4548 - val_accuracy: 0.8158 - val_loss: 1.3609
# Epoch 68/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7651 - loss: 0.5636 - val_accuracy: 0.7895 - val_loss: 2.1428
# Epoch 69/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8013 - loss: 0.4589 - val_accuracy: 0.8355 - val_loss: 1.4074
# Epoch 70/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8319 - loss: 0.4472 - val_accuracy: 0.7763 - val_loss: 2.1461
# Epoch 71/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8320 - loss: 0.4087 - val_accuracy: 0.7961 - val_loss: 2.1740
# Epoch 72/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8041 - loss: 0.5648 - val_accuracy: 0.7763 - val_loss: 2.5363
# Epoch 73/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8010 - loss: 0.4907 - val_accuracy: 0.8421 - val_loss: 1.2935
# Epoch 74/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8372 - loss: 0.4150 - val_accuracy: 0.8224 - val_loss: 1.5497
# Epoch 75/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8196 - loss: 0.4633 - val_accuracy: 0.8421 - val_loss: 0.9692
# Epoch 76/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8042 - loss: 0.5393 - val_accuracy: 0.8026 - val_loss: 1.3331
# Epoch 77/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8206 - loss: 0.4422 - val_accuracy: 0.8421 - val_loss: 1.0343
# Epoch 78/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8137 - loss: 0.5636 - val_accuracy: 0.8684 - val_loss: 0.4297
# Epoch 79/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8239 - loss: 0.4258 - val_accuracy: 0.8092 - val_loss: 1.3496
# Epoch 80/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8341 - loss: 0.4579 - val_accuracy: 0.8355 - val_loss: 0.8926
# Epoch 81/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8361 - loss: 0.4053 - val_accuracy: 0.8487 - val_loss: 1.5977
# Epoch 82/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8376 - loss: 0.4270 - val_accuracy: 0.8289 - val_loss: 1.6347
# Epoch 83/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8253 - loss: 0.4855 - val_accuracy: 0.8355 - val_loss: 1.5546
# Epoch 84/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8203 - loss: 0.4898 - val_accuracy: 0.8618 - val_loss: 2.2313
# Epoch 85/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8277 - loss: 0.4573 - val_accuracy: 0.8421 - val_loss: 0.7404
# Epoch 86/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8685 - loss: 0.3384 - val_accuracy: 0.8684 - val_loss: 0.5392
# Epoch 87/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.8164 - loss: 0.4437 - val_accuracy: 0.8487 - val_loss: 0.8642
# Epoch 88/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8557 - loss: 0.3905 - val_accuracy: 0.8618 - val_loss: 0.8172
# Epoch 89/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8686 - loss: 0.3919 - val_accuracy: 0.8421 - val_loss: 1.0192
# Epoch 90/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8603 - loss: 0.4090 - val_accuracy: 0.8882 - val_loss: 0.7029
# Epoch 91/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8817 - loss: 0.3510 - val_accuracy: 0.8882 - val_loss: 0.7217
# Epoch 92/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8581 - loss: 0.3880 - val_accuracy: 0.8684 - val_loss: 0.7976
# Epoch 93/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.8622 - loss: 0.3323 - val_accuracy: 0.8421 - val_loss: 0.8859
# Epoch 94/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8319 - loss: 0.5771 - val_accuracy: 0.8158 - val_loss: 1.8150
# Epoch 95/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8399 - loss: 0.4156 - val_accuracy: 0.8158 - val_loss: 0.7465
# Epoch 96/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8304 - loss: 0.4106 - val_accuracy: 0.8224 - val_loss: 0.7580
# Epoch 97/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8494 - loss: 0.3469 - val_accuracy: 0.8618 - val_loss: 0.5845
# Epoch 98/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8670 - loss: 0.3942 - val_accuracy: 0.8158 - val_loss: 0.9897
# Epoch 99/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.8395 - loss: 0.3651 - val_accuracy: 0.8092 - val_loss: 0.9071
# Epoch 100/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8464 - loss: 0.3705 - val_accuracy: 0.8026 - val_loss: 1.1498
# Epoch 101/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8185 - loss: 0.5500 - val_accuracy: 0.8355 - val_loss: 0.7479
# Epoch 102/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8560 - loss: 0.4136 - val_accuracy: 0.8487 - val_loss: 0.6483
# Epoch 103/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8609 - loss: 0.3954 - val_accuracy: 0.8553 - val_loss: 0.5153
# Epoch 104/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8559 - loss: 0.3720 - val_accuracy: 0.8158 - val_loss: 1.0605
# Epoch 105/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8468 - loss: 0.3858 - val_accuracy: 0.8684 - val_loss: 0.9131
# Epoch 106/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.8564 - loss: 0.4357 - val_accuracy: 0.8618 - val_loss: 0.8177
# Epoch 107/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8440 - loss: 0.4128 - val_accuracy: 0.8618 - val_loss: 0.8932
# Epoch 108/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8798 - loss: 0.3573 - val_accuracy: 0.8289 - val_loss: 1.0162
# Epoch 109/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8327 - loss: 0.3783 - val_accuracy: 0.8026 - val_loss: 1.5374
# Epoch 110/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8829 - loss: 0.4179 - val_accuracy: 0.8618 - val_loss: 0.7474
# Epoch 111/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8284 - loss: 0.4532 - val_accuracy: 0.8618 - val_loss: 0.7609
# Epoch 112/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.8858 - loss: 0.3082 - val_accuracy: 0.8224 - val_loss: 1.0852
# Epoch 113/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8897 - loss: 0.3351 - val_accuracy: 0.8816 - val_loss: 0.5362
# Epoch 114/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8876 - loss: 0.3331 - val_accuracy: 0.9145 - val_loss: 0.4133
# Epoch 115/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8479 - loss: 0.3794 - val_accuracy: 0.8816 - val_loss: 1.1463
# Epoch 116/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8779 - loss: 0.3897 - val_accuracy: 0.8289 - val_loss: 0.9020
# Epoch 117/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8813 - loss: 0.3272 - val_accuracy: 0.8947 - val_loss: 0.4521
# Epoch 118/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8575 - loss: 0.3493 - val_accuracy: 0.8684 - val_loss: 0.5934
# Epoch 119/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8910 - loss: 0.2657 - val_accuracy: 0.8487 - val_loss: 0.7800
# Epoch 120/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8934 - loss: 0.3039 - val_accuracy: 0.8487 - val_loss: 0.6722
# Epoch 121/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8549 - loss: 0.4072 - val_accuracy: 0.8882 - val_loss: 0.4733
# Epoch 122/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8922 - loss: 0.2756 - val_accuracy: 0.8882 - val_loss: 0.4823
# Epoch 123/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9071 - loss: 0.2964 - val_accuracy: 0.8882 - val_loss: 0.5818
# Epoch 124/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8818 - loss: 0.2675 - val_accuracy: 0.8289 - val_loss: 1.4662
# Epoch 125/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8774 - loss: 0.3714 - val_accuracy: 0.8750 - val_loss: 0.6018
# Epoch 126/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8867 - loss: 0.3852 - val_accuracy: 0.8026 - val_loss: 1.0938
# Epoch 127/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8426 - loss: 0.4062 - val_accuracy: 0.9211 - val_loss: 0.3260
# Epoch 128/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9137 - loss: 0.2475 - val_accuracy: 0.8947 - val_loss: 0.6070
# Epoch 129/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8715 - loss: 0.3322 - val_accuracy: 0.8816 - val_loss: 0.5784
# Epoch 130/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8669 - loss: 0.3485 - val_accuracy: 0.8882 - val_loss: 0.6803
# Epoch 131/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8807 - loss: 0.3695 - val_accuracy: 0.9145 - val_loss: 0.3421
# Epoch 132/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8825 - loss: 0.3088 - val_accuracy: 0.9276 - val_loss: 0.3122
# Epoch 133/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9195 - loss: 0.2392 - val_accuracy: 0.9013 - val_loss: 0.5439
# Epoch 134/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8807 - loss: 0.3127 - val_accuracy: 0.8026 - val_loss: 1.1035
# Epoch 135/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8517 - loss: 0.4381 - val_accuracy: 0.9211 - val_loss: 0.2966
# Epoch 136/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8723 - loss: 0.3706 - val_accuracy: 0.8947 - val_loss: 0.6604
# Epoch 137/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8853 - loss: 0.3413 - val_accuracy: 0.8882 - val_loss: 0.5819
# Epoch 138/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8814 - loss: 0.2864 - val_accuracy: 0.8947 - val_loss: 0.4925
# Epoch 139/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8801 - loss: 0.3121 - val_accuracy: 0.8947 - val_loss: 0.6575
# Epoch 140/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8953 - loss: 0.2729 - val_accuracy: 0.9079 - val_loss: 0.6214
# Epoch 141/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8859 - loss: 0.2916 - val_accuracy: 0.9211 - val_loss: 0.4221
# Epoch 142/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9179 - loss: 0.2665 - val_accuracy: 0.8882 - val_loss: 0.8770
# Epoch 143/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8750 - loss: 0.3002 - val_accuracy: 0.8289 - val_loss: 0.8236
# Epoch 144/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8840 - loss: 0.3622 - val_accuracy: 0.8750 - val_loss: 0.8386
# Epoch 145/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8868 - loss: 0.2550 - val_accuracy: 0.8355 - val_loss: 0.9520
# Epoch 146/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8842 - loss: 0.3076 - val_accuracy: 0.8816 - val_loss: 0.5228
# Epoch 147/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9051 - loss: 0.3111 - val_accuracy: 0.8882 - val_loss: 0.9559
# Epoch 148/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8987 - loss: 0.2473 - val_accuracy: 0.9013 - val_loss: 0.5242
# Epoch 149/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9041 - loss: 0.2507 - val_accuracy: 0.9079 - val_loss: 0.5186
# Epoch 150/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8710 - loss: 0.3308 - val_accuracy: 0.9079 - val_loss: 0.4346
# Epoch 151/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9126 - loss: 0.2422 - val_accuracy: 0.8882 - val_loss: 0.6384
# Epoch 152/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9110 - loss: 0.2656 - val_accuracy: 0.8750 - val_loss: 0.5622
# Epoch 153/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9111 - loss: 0.2659 - val_accuracy: 0.9013 - val_loss: 0.6051
# Epoch 154/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9227 - loss: 0.2286 - val_accuracy: 0.8816 - val_loss: 0.6044
# Epoch 155/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9056 - loss: 0.2967 - val_accuracy: 0.8882 - val_loss: 0.4924
# Epoch 156/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8942 - loss: 0.3000 - val_accuracy: 0.8684 - val_loss: 0.7841
# Epoch 157/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9177 - loss: 0.3254 - val_accuracy: 0.8684 - val_loss: 0.7846
# Epoch 158/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9064 - loss: 0.2945 - val_accuracy: 0.9276 - val_loss: 0.3443
# Epoch 159/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9158 - loss: 0.2027 - val_accuracy: 0.8882 - val_loss: 0.7980
# Epoch 160/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9385 - loss: 0.2023 - val_accuracy: 0.8947 - val_loss: 0.4018
# Epoch 161/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8999 - loss: 0.2515 - val_accuracy: 0.8684 - val_loss: 0.6388
# Epoch 162/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9010 - loss: 0.2929 - val_accuracy: 0.8487 - val_loss: 1.7563
# Epoch 163/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9132 - loss: 0.2390 - val_accuracy: 0.8816 - val_loss: 0.8912
# Epoch 164/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8755 - loss: 0.3251 - val_accuracy: 0.9145 - val_loss: 0.3826
# Epoch 165/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8830 - loss: 0.2750 - val_accuracy: 0.9079 - val_loss: 0.4633
# Epoch 166/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9173 - loss: 0.2429 - val_accuracy: 0.9145 - val_loss: 0.3821
# Epoch 167/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.8977 - loss: 0.3046 - val_accuracy: 0.9145 - val_loss: 0.4340
# Epoch 168/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8841 - loss: 0.2918 - val_accuracy: 0.8947 - val_loss: 0.7137
# Epoch 169/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8796 - loss: 0.3342 - val_accuracy: 0.9079 - val_loss: 0.4169
# Epoch 170/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9330 - loss: 0.2419 - val_accuracy: 0.9211 - val_loss: 0.4159
# Epoch 171/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8764 - loss: 0.3255 - val_accuracy: 0.8947 - val_loss: 0.5214
# Epoch 172/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9056 - loss: 0.2898 - val_accuracy: 0.9211 - val_loss: 0.2907
# Epoch 173/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9141 - loss: 0.2420 - val_accuracy: 0.9276 - val_loss: 0.3556
# Epoch 174/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8767 - loss: 0.2937 - val_accuracy: 0.9079 - val_loss: 0.6671
# Epoch 175/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9180 - loss: 0.2315 - val_accuracy: 0.9145 - val_loss: 0.4285
# Epoch 176/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9056 - loss: 0.2757 - val_accuracy: 0.9013 - val_loss: 0.8464
# Epoch 177/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9049 - loss: 0.2152 - val_accuracy: 0.9605 - val_loss: 0.1864
# Epoch 178/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9157 - loss: 0.2514 - val_accuracy: 0.9079 - val_loss: 0.5327
# Epoch 179/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9272 - loss: 0.1947 - val_accuracy: 0.8750 - val_loss: 0.9166
# Epoch 180/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8647 - loss: 0.3600 - val_accuracy: 0.8618 - val_loss: 0.7557
# Epoch 181/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8857 - loss: 0.3674 - val_accuracy: 0.9276 - val_loss: 0.2325
# Epoch 182/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8870 - loss: 0.2996 - val_accuracy: 0.9342 - val_loss: 0.5517
# Epoch 183/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9262 - loss: 0.2352 - val_accuracy: 0.8618 - val_loss: 0.9258
# Epoch 184/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8833 - loss: 0.2588 - val_accuracy: 0.8882 - val_loss: 0.7646
# Epoch 185/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9056 - loss: 0.2527 - val_accuracy: 0.8224 - val_loss: 1.3184
# Epoch 186/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9114 - loss: 0.3016 - val_accuracy: 0.9342 - val_loss: 0.2327
# Epoch 187/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9271 - loss: 0.2105 - val_accuracy: 0.9013 - val_loss: 0.5133
# Epoch 188/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9189 - loss: 0.2788 - val_accuracy: 0.9079 - val_loss: 0.4713
# Epoch 189/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9064 - loss: 0.2643 - val_accuracy: 0.9211 - val_loss: 0.3510
# Epoch 190/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9271 - loss: 0.2164 - val_accuracy: 0.9079 - val_loss: 0.4591
# Epoch 191/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9329 - loss: 0.2020 - val_accuracy: 0.9408 - val_loss: 0.3453
# Epoch 192/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9182 - loss: 0.2350 - val_accuracy: 0.9474 - val_loss: 0.1435
# Epoch 193/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9264 - loss: 0.1897 - val_accuracy: 0.9079 - val_loss: 0.8369
# Epoch 194/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9291 - loss: 0.2212 - val_accuracy: 0.8947 - val_loss: 0.6649
# Epoch 195/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9012 - loss: 0.2961 - val_accuracy: 0.8947 - val_loss: 0.5381
# Epoch 196/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9350 - loss: 0.1822 - val_accuracy: 0.9145 - val_loss: 0.4132
# Epoch 197/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9308 - loss: 0.1956 - val_accuracy: 0.9342 - val_loss: 0.4116
# Epoch 198/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9244 - loss: 0.2351 - val_accuracy: 0.9211 - val_loss: 0.3759
# Epoch 199/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9195 - loss: 0.2116 - val_accuracy: 0.9342 - val_loss: 0.3029
# Epoch 200/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9302 - loss: 0.2174 - val_accuracy: 0.8750 - val_loss: 0.7573

# %%
def predict_on_video(model, video_path, frames_to_extract=45):
    np_array = convert_video_to_pose_embedded_np_array(video_path, frames_to_extract)
    np_array = np.expand_dims(np_array, axis=0)  # Expand dimensions to match input shape
    prediction = model.predict(np_array)
    predicted_class = np.argmax(prediction, axis=1)
    return predicted_class[0]

# Test the model on a single input video
test_video_path = '/content/drive/My Drive/Datasets/Greetings/48. Hello/MVI_0029.MOV'  # Replace with your test video path
predicted_class = predict_on_video(model, test_video_path, frames_to_extract)
print(f"Predicted class: {list(label_map.keys())[list(label_map.values()).index(predicted_class)]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted class: 48. Hello

# %%
model.save('/content/drive/My Drive/Weights/SignLanguage/sign_language.h5')
model.save_weights('/content/drive/My Drive/Weights/SignLanguage/sign_language_weights.weights.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
